# %%
import cv2
import numpy as np # <-- CORRECTED LINE
import matplotlib.pyplot as plt
gambar = cv2.imread(r'C:\Pengelola citra digital\unpam.png')

# Rest of your code
histogram = cv2.calcHist([gambar], [0], None, [256], [0,256])

plt.figure()
plt.title('Histogram original image')
plt.xlabel('intesitas Pixel')
plt.ylabel('Jumlah Pixel')
plt.plot(histogram)
plt.xlim(0,256)
plt.show()

# %%
gambar = cv2.imread(r'C:\Pengelola citra digital\unpam.png', cv2.IMREAD_GRAYSCALE)
if gambar is None: print("Error: Gambar tidak dapat dimuat") 
exit()
gambar_eskualisasi = cv2.equalizelHist(gambar)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Gambar Asli')
plt.imshow(gambar, cmap='gray')
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Gambar Ekualisasi')
plt.imshow(gambar_ekualisasi, cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       2 if gambar is None: print("Error: Gambar tidak dapat dimuat")
#       3 exit()
# ----> 4 gambar_eskualisasi = cv2.equalizelHist(gambar)
#       6 plt.figure(figsize=(12,5))
#       7 plt.subplot(1,2,1)
#
# AttributeError: module 'cv2' has no attribute 'equalizelHist'

# %%
import cv2
import matplotlib.pyplot as plt

# Memuat gambar dalam mode grayscale
gambar = cv2.imread('C:\Pengelola citra digital\unpam.png', cv2.IMREAD_GRAYSCALE)

if gambar is None:
    print("Error: Gambar tidak dapat dimuat")
    exit() 
    
# PERBAIKAN: Menggunakan equalizeHist (dengan 'e')
gambar_ekualisasi = cv2.equalizeHist(gambar) 

plt.figure(figsize=(12,5))

# Plot Gambar Asli
plt.subplot(1,2,1)
plt.title('Gambar Asli')
plt.imshow(gambar, cmap='gray')
plt.axis('off')

# Plot Gambar Ekualisasi
plt.subplot(1,2,2)
plt.title('Gambar Ekualisasi')
plt.imshow(gambar_ekualisasi, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
histogram_asli = cv2
# Out:
#   Cell In[4], line 5
#     gambar = cv2.imread('C:\Pengelola citra digital\unpam.png', cv2.IMREAD_GRAYSCALE)
#                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 26-27: truncated \uXXXX escape

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1. Baca gambar dalam grayscale
gambar = cv2.imread('unpam.png', cv2.IMREAD_GRAYSCALE)

if gambar is None:
    print("Error: Gambar tidak dapat dimuat!")
    exit()

# 2. Lakukan ekualisasi histogram
gambar_ekualisasi = cv2.equalizeHist(gambar)

# 3. Tampilkan gambar asli dan hasil ekualisasi
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.title('Gambar Asli')
plt.imshow(gambar, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Gambar Ekualisasi')
plt.imshow(gambar_ekualisasi, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# 4. Hitung dan tampilkan histogram keduanya
plt.figure(figsize=(12, 5))

# Histogram gambar asli
plt.subplot(1, 2, 1)
histogram_asli = cv2.calcHist([gambar], [0], None, [256], [0, 256])
plt.title('Histogram Gambar Asli')
plt.plot(histogram_asli)
plt.xlim([0, 256])
plt.grid(True)

# Histogram gambar ekualisasi
plt.subplot(1, 2, 2)
histogram_ekualisasi = cv2.calcHist([gambar_ekualisasi], [0], None, [256], [0, 256])
plt.title('Histogram Gambar Ekualisasi')
plt.plot(histogram_ekualisasi)
plt.xlim([0, 256])
plt.grid(True)

plt.tight_layout()
plt.show()
